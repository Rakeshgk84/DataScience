# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import requests 
from io import StringIO
from io import BytesIO
import numpy as np
import pandas as pd # pandas
import matplotlib.pyplot as plt # module for plotting 
import datetime as dt # module for manipulating dates and times
import numpy.linalg as lin # module for performing linear algebra operations

# %%
url = 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcurrent'

# %%
pd_url = pd.read_clipboard(url)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-738e48354624> in <module>()
# ----> 1 pd_url = pd.read_clipboard(url)
#
# TypeError: read_clipboard() takes 0 positional arguments but 1 was given

# %%
request = requests.get(url)

# %%
pd_url
# Out:
#     <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# 0                                    <html lang="ENG">
# 1                                               <head>
# 2                  <title>Latest EDGAR Filings</title>
# 3                                <!-- BEGIN HEADER -->
# 4    <script language="JavaScript" src="/include/se...
# 5    <link rel="alternate" type="application/atom+x...
# 6                                              </head>
# 7                             <body style="margin: 0">
# 8    <!-- SEC Web Analytics - For information pleas...
# 9    <noscript><iframe src="//www.googletagmanager....
# 10   height="0" width="0" style="display:none;visib...
# 11   <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l...
# 12   new Date().getTime(),event:'gtm.js'});var f=d....
# 13   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l...
# 14   '//www.googletagmanager.com/gtm.js?id='+i+dl;f...
# 15   })(window,document,'script','dataLayer','GTM-T...
# 16                      <!-- End SEC Web Analytics -->
# 17   <table border="0" width="100%" cellpadding="0"...
# 18                                                <tr>
# 19    <td width="95" rowspan="2"><a href="/index.htm">
# 20   <img src="/images/bannerSeal.gif" width="95" h...
# 21   <td colspan="2"><img src="/images/pixel.gif" w...
# 22                                               </tr>
# 23                                                <tr>
# 24   <td width="26"><img src="/images/bannerSealR.g...
# 25                      <td width="100%" valign="top">
# 26   <table width="100%" border="0" cellpadding="0"...
# 27                                                <tr>
# 28   <td width="171" bgcolor="#324395" valign="top"...
# 29   <td width="95%" align="right" valign="middle" ...
# ..                                                 ...
# 554    <td nowrap="nowrap">2016-10-20<br>19:42:33</td>
# 555      <td nowrap="nowrap">2016-10-20</td></td></tr>
# 556                                           <tr><td>
# 557                                               <td>
# 558  <td bgcolor="#E6E6E6" valign="top" align="left...
# 559                                              </tr>
# 560     <tr nowrap="nowrap" valign="top" align="left">
# 561                         <td nowrap="nowrap">4</td>
# 562  <td nowrap="nowrap"><a href="/Archives/edgar/d...
# 563  <td class="small">Statement of changes in bene...
# 564                                              </td>
# 565    <td nowrap="nowrap">2016-10-20<br>19:42:33</td>
# 566  <td nowrap="nowrap">2016-10-20</td><td nowrap=...
# 567                            <br>161945139</td></tr>
# 568                                           </table>
# 569  <form> <input type="button" value="Next 40" on...
# 570                                         </form><P>
# 571  <i>http://www.sec.gov/cgi-bin/browse-edgar</i>...
# 572                              <!-- BEGIN FOOTER -->
# 573                                      <hr size="1">
# 574                                             </div>
# 575         <table width="100%" border="0" summary="">
# 576                                  <tr valign="top">
# 577  <td class="footer"><a href="/index.htm">Home</...
# 578  <td align="right" valign="top"><h6>Modified: 0...
# 579                                              </tr>
# 580                                           </table>
# 581                                   <!-- </font> -->
# 582                                            </body>
# 583                                            </html>
#
# [584 rows x 1 columns]

# %%
pd_urls.head()
# Out:
# Empty DataFrame
# Columns: [<h1>596 Service Not Found</h1>]
# Index: []
